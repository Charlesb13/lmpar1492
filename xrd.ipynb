# %%
from pymatgen.ext.matproj import MPRester
from pymatgen.io.cif import CifWriter
from IPython.display import FileLink
from pymatgen.analysis.diffraction.xrd import XRDCalculator

# %%
key = "n58KMF7umZMAJXouXDJc0vORWlcEfEsD"  
material = "mp-23209"   
m = MPRester(key)
struct = m.get_structure_by_material_id(material,conventional_unit_cell=True)
# Out:
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
xrd = XRDCalculator(1.54060)
dif = xrd.get_pattern(struct)
for i in range(3):
    print("Pic numéro "+str(i+1))
    print("Angle du pic : "+str(dif.x[i]))
    print("Intensité du pic : "+str(dif.y[i]))
    print("Indices hkl du pic : "+str(dif.hkls[i][0]["hkl"]))
    print("Multiplicité du pic : "+str(dif.hkls[i][0]["multiplicity"]))
    print(" ")
xrd.show_plot(struct,two_theta_range=[0,180])
# Out:
# Pic numéro 1
# Angle du pic : 21.977188441050103
# Intensité du pic : 74.86345560841018
# Indices hkl du pic : (1, 1, 1)
# Multiplicité du pic : 8
#
# Pic numéro 2
# Angle du pic : 25.430001529931452
# Intensité du pic : 0.8754789697648353
# Indices hkl du pic : (2, 0, 0)
# Multiplicité du pic : 6
#
# Pic numéro 3
# Angle du pic : 36.27164775904004
# Intensité du pic : 100.0
# Indices hkl du pic : (2, 2, 0)
# Multiplicité du pic : 12
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 10
#       8     print("Multiplicité du pic : "+str(dif.hkls[i][0]["multiplicity"]))
#       9     print(" ")
# ---> 10 xrd.show_plot(struct,two_theta_range=[0,180])
#
# File /usr/local/lib64/python3.9/site-packages/pymatgen/analysis/diffraction/core.py:170, in AbstractDiffractionPatternCalculator.show_plot(self, structure, **kwargs)
#     155 def show_plot(self, structure: Structure, **kwargs):
#     156     """
#     157     Shows the diffraction plot.
#     158
#    (...)
#     168             long version, e.g. (1, 0, 0). If None, do not show anything.
#     169     """
# --> 170     self.get_plot(structure, **kwargs).show()
#
# AttributeError: 'Axes' object has no attribute 'show'
